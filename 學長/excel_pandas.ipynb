# %%
import os 
import pandas as pd

path_src='C:\\Users\\TMU_AIMC\\Desktop\\james\\學長'
file_name='20191118.xlsx'
df=pd.read_excel(os.path.join(path_src,file_name), header=None)
df_A_L=df.copy()
# # 讀取1~12欄的資料 法一
# column_ls=df.columns
# tmp_col=df[column_ls[0:12]]

# 讀取1~12欄的資料 法二
tmp_col=df_A_L.ix[: , 0:11]
tmp_col
# Out:
# C:\Users\TMU_AIMC\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   del sys.path[0]
# C:\Users\TMU_AIMC\Anaconda3\lib\site-packages\pandas\core\indexing.py:822: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#       0               1           2             3       4   \
# 0     編號        Hospital   品質檢查人員/日期        品質檢查狀態  Biopsy
# 1      1             SHH         藍功堯            OK  biopsy
# 2      2             SHH         藍功堯           待重檢  biopsy
# ...

# %%
columns=['Hospital','Biopsy']
df.drop(columns,axis=1) 
df
#axis: 0表示刪除行，1表示刪除列
#inplace: False表示源 DataFrame 不變（預設）
#True 表示源 DataFrame改變
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-35bb48942984> in <module>
#       1 columns=['Hospital','Biopsy']
# ----> 2 df.drop(columns,axis=1)
#       3 df
#       4 #axis: 0表示刪除行，1表示刪除列
#       5 #inplace: False表示源 DataFrame 不變（預設）
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
df_A_L=pd.read_clipboard()
df_A_L
df_A_L.to_excel('A2L_col.xlsx',index=False) # index=false 不顯示行索引

# %%
path_dst='C:\\Users\\TMU_AIMC\\Desktop\\james\\學長'
file_name='A2L_col.xlsx'
data_pd=pd.read_excel(os.path.join(path_dst,file_name))
# single
filter=data_pd['num1']==1
filter_single_A2L=data_pd[filter]

filter_single_A2L.to_excel('filter_single_A2L.xlsx',index=False)

# %%
# multiple
filter=data_pd['num1']>1
filter_multiple_A2L=data_pd[filter]

filter_multiple_A2L.to_excel('filter_multiple_A2L.xlsx',index=False)

filter_multiple_A2L
# Out:
#       編號             Hospital    品質檢查人員/日期        品質檢查狀態          Biopsy  \
# 13    14                  SHH    LAN6/24不修  ROI modified          biopsy
# 24    25                  SHH    LAN6/24不修            OK          biopsy
# 93    94                  SHH      LAN6/25  ROI modified          biopsy
# 94    95                  SHH      LAN6/25  ROI modified       no biopsy
# 95    96                  SHH      LAN6/25  ROI modified       no biopsy
# 96    97                  SHH      LAN6/25  ROI modified       no biopsy
# 102  103                  SHH      LAN6/25  ROI modified       no biopsy
# 103  104                  SHH      LAN6/25  ROI modified       no biopsy
# 167  168                  SHH  Dr.LAN06/26            OK       no biopsy
# 176  177                  SHH  Dr.LAN06/26  ROI modified       no biopsy
# 179  180                  SHH  Dr.LAN06/26  ROI modified          biopsy
# 184  185                  SHH  Dr.LAN06/26  ROI modified       no biopsy
# ...

# %%
df_M_AH=pd.read_clipboard()
df_M_AH
df_M_AH.to_excel('M2AH_col.xlsx',index=False)

# %%
df_AI_AM=pd.read_clipboard()
df_AI_AM
df_AI_AM.to_excel('AI2AM_col.xlsx',index=False)

# %%
df_A_L.query("num1=='1'")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     187             if self.has_resolvers:
# --> 188                 return self.resolvers[key]
#     189
#
# ~\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# ~\Anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'num1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = pd.read_csv('http://bit.ly/kaggletrain')
df = df.drop("Name", axis=1)
# df.head()
df.loc[:3,'Pclass':'Ticket']
# Out:
#    Pclass     Sex   Age  SibSp  Parch            Ticket
# 0       3    male  22.0      1      0         A/5 21171
# 1       1  female  38.0      1      0          PC 17599
# 2       3  female  26.0      0      0  STON/O2. 3101282
# 3       1  female  35.0      1      0            113803

# %%
df.query("Sex=='male'")
# Out:
#      PassengerId  Survived  Pclass   Sex   Age  SibSp  Parch  \
# 0              1         0       3  male  22.0      1      0
# 4              5         0       3  male  35.0      0      0
# 5              6         0       3  male   NaN      0      0
# 6              7         0       1  male  54.0      0      0
# 7              8         0       3  male   2.0      3      1
# ..           ...       ...     ...   ...   ...    ...    ...
# 883          884         0       2  male  28.0      0      0
# 884          885         0       3  male  25.0      0      0
# 886          887         0       2  male  27.0      0      0
# 889          890         1       1  male  26.0      0      0
# 890          891         0       3  male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 4              373450   8.0500   NaN        S
# 5              330877   8.4583   NaN        Q
# ...

# %%
male_and_age_over_70 = (df.Sex == 'male') & (df.Age > 70)
(df[male_and_age_over_70]
    .style
    .applymap(lambda x: 'background-color: rgb(153, 255, 51)', 
              subset=pd.IndexSlice[:, 'Sex':'Age']))
# Out:
# <style  type="text/css" >
#     #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row0_col3 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row0_col4 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row1_col3 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row1_col4 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row2_col3 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row2_col4 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row3_col3 {
#             background-color:  rgb(153, 255, 51);
#         }    #T_9bf79980_0a72_11ea_b8b1_b42e9942d331row3_col4 {
#             background-color:  rgb(153, 255, 51);
# ...

# %%
# 找出符合特定字串的樣本
df = pd.read_csv('http://bit.ly/kaggletrain')
df[df.Name.str.contains("Mr\.")].head(5)
# contains 函式接受的是正規表示式，因此需要將 . 轉換成 \.
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 5             6         0       3                Moran, Mr. James  male   NaN
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked
# 0       1      0  A/5 21171   7.2500   NaN        S
# 4       0      0     373450   8.0500   NaN        S
# 5       0      0     330877   8.4583   NaN        Q
# 6       0      0      17463  51.8625   E46        S
# 12      0      0  A/5. 2151   8.0500   NaN        S

# %%
# 樞紐分析表(pivot table)
import seaborn as sns
df=sns.load_dataset('titanic')
df.pivot_table('survived', index='sex',columns='class')
# Out:
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447
