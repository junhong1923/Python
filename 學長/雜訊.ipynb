# %%
#彩色轉灰階
Intensity=(R+G+B)/3
Gray=0.299R+ 0.587G+ 0.114B

# %%
# 頻率60的sin波
import math
import numpy as np
import matplotlib.pyplot as plt

deg=range(0,1000,1)
rad=[ele*math.pi / 180 for ele in deg]

def func_getsin(rad):
    return math.sin(rad)

f_sin=np.vectorize(func_getsin)

y_sin=f_sin(rad)
n=np.random.randn(1000)
#畫圖
plt.figure()
plt.plot( rad,n,rad,y_sin)

ax=plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 1, 1000)

noise= np.random.randn(1000)


y = np.sin(x*60*2*math.pi)  
plt.plot(x,noise, x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma=0,1 # mu is average, sigma is standard deviation
noise=np.random.normal(mu,sigma, 1000)

# %%
np.std(noise)
# Out:
# 0.9666074857003344

# %%
np.mean(noise)
# Out:
# 0.03395763455508247

# %%
print(np.min(noise), np.max(noise))
# Out:
# -2.615064018245513 4.177900918117711

# %%
f=60
omega=2*np.pi*f
t=np.linspace(-2/f, 2/f, 1000)
def f(t):
    return np.sin(omega*t)

# %%
plt.figure(gifsize=(10,5))
fig1=plt.plot(t,noise,c)
